# %% [markdown]
# # Unit 2 — Advanced Visualization & Storytelling (UE24CS342AA9)
# ## Activity Notebook: Build an Interactive Retail Sales Dashboard
#
# ### Scenario
#
# You have just joined the analytics team of **UrbanCart**, a mid-sized retail chain with stores across
# three regions. Regional managers currently receive a static monthly PDF report and complain that:
#
# 1. They can't drill into *why* a number moved without emailing the analytics team.
# 2. Comparing stores or products side by side means flipping between many separate PDF pages.
# 3. Spotting a sudden dip in a specific product/store is slow and easy to miss.
#
# **Your job:** apply the interaction techniques from the lecture — dynamic queries, coordinated views
# & brushing, table lens, focus+context drill-down, and single-screen dashboard design — to build an
# **interactive exploration tool** that solves these three complaints.
#
# ### How this notebook is organized
#
# - A sample dataset is generated for you (Task 0) — don't skip running it.
# - Each task states the **real-world usage**: which complaint above it solves, and why the technique
#   fits.
# - Tasks give you a **scaffold** (imports, helper stubs, expected output) — **you write the core logic**
#   marked with `# TODO`. Do not just copy the Demo notebook's code verbatim — the data shape, column
#   names and the exact question being asked are different here, so you will need to adapt the pattern,
#   not paste it.
#
#
# > **Grading-relevant tip:** every `# TODO` cell tells you what the final variable/plot must be named
# > or show — read it before coding, since later cells depend on it.

# %% [markdown]
# ## Task 0 — Load the Sample Dataset (provided)
#
# Run the cells below as-is. This generates `sales_df`: 24 months of daily-aggregated sales across
# 6 stores (3 regions), 10 products (4 categories), including revenue, profit and customer ratings —
# enough structure to support every technique you'll build below.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns

import plotly.express as px
import plotly.graph_objects as go

import ipywidgets as widgets
from ipywidgets import interact, HBox, VBox

sns.set_theme(style="whitegrid")
np.random.seed(7)
print("Libraries loaded.")
# Out:
# Libraries loaded.

# %%
# --- Sample dataset generator: UrbanCart retail sales (provided, do not need to modify) ---
stores = pd.DataFrame({
    "store_id":   ["S01", "S02", "S03", "S04", "S05", "S06"],
    "store_city": ["Bengaluru", "Mysuru", "Mumbai", "Pune", "Delhi", "Jaipur"],
    "region":     ["South", "South", "West", "West", "North", "North"],
})

products = pd.DataFrame({
    "product":  ["Wireless Earbuds", "Smartwatch", "Laptop Sleeve", "USB-C Hub",
                 "Yoga Mat", "Dumbbell Set", "Running Shoes", "Track Jacket",
                 "Air Fryer", "Blender"],
    "category": ["Electronics", "Electronics", "Electronics", "Electronics",
                 "Fitness", "Fitness", "Apparel", "Apparel",
                 "Home", "Home"],
    "unit_price": [1499, 4999, 899, 1299, 799, 2499, 3499, 1999, 3999, 2299],
})

months = pd.date_range("2023-01-01", periods=24, freq="MS")

rows = []
for _, s in stores.iterrows():
    store_scale = np.random.uniform(0.7, 1.4)          # some stores just sell more
    for _, p in products.iterrows():
        product_scale = np.random.uniform(0.6, 1.6)
        trend = np.random.normal(0.01, 0.01)             # slow month-over-month growth/decline
        for i, m in enumerate(months):
            seasonal = 1 + 0.25 * np.sin(2 * np.pi * (m.month / 12))   # yearly seasonality
            units = max(0, np.random.poisson(15 * store_scale * product_scale * seasonal * (1 + trend) ** i))
            revenue = units * p["unit_price"]
            profit_margin = np.random.uniform(0.12, 0.35)
            profit = revenue * profit_margin
            rating = np.clip(np.random.normal(4.1, 0.4), 1, 5)
            # NOTE: use bracket indexing (p["product"]), not p.product -- pandas Series already has
            # a built-in .product() method, so attribute access on a column literally named "product"
            # silently returns that method instead of your data. This is a common real-world gotcha.
            rows.append((m, s["store_id"], s["store_city"], s["region"], p["product"], p["category"],
                         p["unit_price"], units, revenue, profit, round(rating, 1)))

sales_df = pd.DataFrame(rows, columns=[
    "month", "store_id", "store_city", "region", "product", "category",
    "unit_price", "units_sold", "revenue", "profit", "avg_rating"
])
for _col in ["units_sold", "revenue", "profit"]:
    sales_df[_col] = sales_df[_col].astype(float)  # float, so the anomaly injection below can scale them

# Inject one deliberate "anomaly" for Task 4 (a real dip a manager would want to investigate)
mask = (sales_df.store_id == "S03") & (sales_df["product"] == "Smartwatch") & (sales_df.month == "2024-06-01")
sales_df.loc[mask, ["units_sold", "revenue", "profit"]] = sales_df.loc[mask, ["units_sold", "revenue", "profit"]] * 0.15

print(sales_df.shape)
sales_df.head()
# Out:
# (1440, 11)
#        month store_id store_city region           product     category  \
# 0 2023-01-01      S01  Bengaluru  South  Wireless Earbuds  Electronics
# 1 2023-02-01      S01  Bengaluru  South  Wireless Earbuds  Electronics
# 2 2023-03-01      S01  Bengaluru  South  Wireless Earbuds  Electronics
# 3 2023-04-01      S01  Bengaluru  South  Wireless Earbuds  Electronics
# 4 2023-05-01      S01  Bengaluru  South  Wireless Earbuds  Electronics
#
#    unit_price  units_sold  revenue        profit  avg_rating
# 0        1499        17.0  25483.0   4631.305022         3.9
# 1        1499        19.0  28481.0   8682.717042         3.8
# 2        1499        16.0  23984.0   8014.910391         4.0
# 3        1499        31.0  46469.0  11438.468953         4.8
# 4        1499        22.0  32978.0   5511.128059         4.2

# %% [markdown]
# **Reflection (answer in a sentence or two, in this markdown cell):**
# Before writing any code, look at the columns above. Which columns would you use as *filters* for
# dynamic querying, and which would you use to *link* views together for brushing? Write your answer
# here.
#
# _Your answer:_
# For dynamic querying (filters), I would use `unit_price`, `units_sold`, `revenue`, `profit`, and `month` (for date ranges). For linking views together (brushing), I would use categorical identifiers like `store_id`, `product`, `category`, and `region`.

# %% [markdown]
# ## Task 1 — Static vs. Interactive: Which Report Actually Answers the Manager's Question?
#
# **Real-world usage:** Complaint #1 ("flipping through PDF pages"). A regional manager asks:
# *"Show me total revenue by product, and let me check exactly how much any bar is worth without
# squinting at a printed axis."*
#
# **Why this technique:** A static bar chart is fine for the *headline* number, but it can't answer a
# precise follow-up question live — that needs a hover-enabled interactive chart (Slide 4-8).
#
# ### Your task
# 1. Build a **static** `matplotlib`/`seaborn` bar chart of total revenue per `product`, sorted
#    descending.
# 2. Build the **same** chart as an **interactive** `plotly` bar chart where hovering shows the exact
#    revenue figure and the category of that product.
# 3. In the markdown cell below, state in 1-2 sentences: for *this specific* manager request, which
#    version wins, and why (tie your answer to target-audience / data-story / ROI from the slide).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns

import plotly.express as px
import plotly.graph_objects as go

import ipywidgets as widgets
from ipywidgets import interact, HBox, VBox

sns.set_theme(style="whitegrid")
np.random.seed(7)
print("Libraries loaded.")

# --- 1a. STATIC chart ---
# TODO:
#   - Group sales_df by "product", sum "revenue"
#   - Sort descending
#   - Plot a horizontal or vertical bar chart with matplotlib/seaborn
#   - Title it clearly

revenue_by_product = sales_df.groupby("product")["revenue"].sum().sort_values(ascending=False).reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x="revenue", y="product", data=revenue_by_product, palette="viridis")
plt.title("Total Revenue by Product (Static)")
plt.xlabel("Total Revenue")
plt.ylabel("Product")
plt.tight_layout()
plt.show()
# Out:
# Libraries loaded.
# /tmp/ipykernel_609/1582537051.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="revenue", y="product", data=revenue_by_product, palette="viridis")

# %%
# --- 1b. INTERACTIVE chart ---
# TODO:
#   - Use plotly.express.bar on the SAME grouped data
#   - Add a hover field for "category" (hint: you'll need category alongside revenue -- think about
#     what columns your groupby needs to keep)
#   - Title it clearly

revenue_by_product_category = sales_df.groupby(["product", "category"])["revenue"].sum().sort_values(ascending=False).reset_index()

fig = px.bar(revenue_by_product_category,
             x="revenue",
             y="product",
             orientation='h',
             title="Total Revenue by Product (Interactive)",
             hover_data=["category"],
             color="revenue",
             color_continuous_scale="viridis")

fig.update_layout(yaxis={'categoryorder':'total ascending'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="37f128eb-3b9c-4983-ae51-0c8c48cfc848" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37f128eb-3b9c-4983-ae51-0c8c48cfc848")) {                    Plotly.newPlot(                        "37f128eb-3b9c-4983-ae51-0c8c48cfc848",                        [{"alignmentgroup":"True","customdata":[["Electronics"],["Home"],["Apparel"],["Fitness"],["Home"],["Apparel"],["Electronics"],["Electronics"],["Electronics"],["Fitness"]],"hovertemplate":"revenue=%{marker.color}\u003cbr\u003eproduct=%{y}\u003cbr\u003ecategory=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[15706358.1,10901274.0,9688731.0,7796880.0,7648773.0,6992502.0,3842442.0,3769985.0,2801284.0,1560447.0],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[15706358.1,10901274.0,9688731.0,7796880.0,7648773.0,6992502.0,3842442.0,3769985.0,2801284.0,1560447.0],"xaxis":"x","y":["Smartwatch","Air Fryer","Running Shoes","Dumbbell Set","Blender","Track Jacket","USB-C Hub","Wireless Earbuds","Laptop Sleeve","Yoga Mat"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"ov ...

# %% [markdown]
# **Your 1-2 sentence answer:**
# For this specific manager request, the interactive Plotly chart wins. It allows the manager to hover and see exact revenue figures and product categories without needing to squint at axes or switch between multiple static reports, directly addressing the complaint of 'flipping through PDF pages' and enabling quicker, self-served insights.

# %% [markdown]
# ## Task 2 — Dynamic Queries: Let Managers Filter Without Asking You
#
# **Real-world usage:** Regional managers want to self-serve answer questions like *"which
# products, in what price range, sold above X units last month?"* without emailing the analytics team
# every time (Complaint #1 again, but for filtering rather than just reading).
#
# **Why this technique:** Dynamic queries (double-ended range sliders) let the pattern emerge from the
# noise live, with the response updating in real time (Slide 23).
#
# ### Your task
# Build **two** linked `ipywidgets` range sliders:
# - `price_slider` — filters on `unit_price`
# - `units_slider` — filters on `units_sold`
#
# Write a function `dynamic_filter(price_range, units_range)` that:
# 1. Filters `sales_df` to rows where `unit_price` is inside `price_range` **and** `units_sold` is
#    inside `units_range`.
# 2. Prints how many rows match out of the total.
# 3. Shows a scatter plot of `unit_price` vs `units_sold`, with matching rows highlighted in a
#    distinct color against all other rows in gray (same pattern as the Demo notebook's dynamic query
#    cell — but you must build the filter condition and the plot yourself for these two columns).
#
# Wire it up with `interact()`.

# %%
price_slider = widgets.FloatRangeSlider(
    value=[sales_df['unit_price'].min(), sales_df['unit_price'].max()],
    min=sales_df['unit_price'].min(),
    max=sales_df['unit_price'].max(),
    step=100,
    description='Unit Price Range:',
    disabled=False,
    continuous_update=True,
    orientation='horizontal',
    readout=True,
    readout_format='$.2f',
)

units_slider = widgets.IntRangeSlider(
    value=[sales_df['units_sold'].min(), sales_df['units_sold'].max()],
    min=sales_df['units_sold'].min(),
    max=sales_df['units_sold'].max(),
    step=1,
    description='Units Sold Range:',
    disabled=False,
    continuous_update=True,
    orientation='horizontal',
    readout=True,
    readout_format='d',
)

def dynamic_filter(price_range, units_range):
    filtered = sales_df[
        (sales_df['unit_price'] >= price_range[0]) & (sales_df['unit_price'] <= price_range[1]) &
        (sales_df['units_sold'] >= units_range[0]) & (sales_df['units_sold'] <= units_range[1])
    ]

    print(f"{len(filtered)} / {len(sales_df)} rows match")

    plt.figure(figsize=(10, 6))
    # Plot all rows in gray
    plt.scatter(sales_df['unit_price'], sales_df['units_sold'], color='lightgray', alpha=0.5, label='All Rows')
    # Plot filtered rows in a distinct color
    plt.scatter(filtered['unit_price'], filtered['units_sold'], color='skyblue', label='Matching Rows')
    plt.title('Unit Price vs. Units Sold (Dynamic Filter)')
    plt.xlabel('Unit Price')
    plt.ylabel('Units Sold')
    plt.legend()
    plt.grid(True)
    plt.show()

interact(dynamic_filter, price_range=price_slider, units_range=units_slider);
# Out:
# interactive(children=(FloatRangeSlider(value=(799.0, 4999.0), description='Unit Price Range:', max=4999.0, min…

# %% [markdown]
# **Reflection:** The slide notes dynamic queries work well "up to ~100,000 points with five or fewer
# sliders." `sales_df` has far fewer rows. If UrbanCart grew to 500 stores and this dataset became 50x
# larger, would two sliders still be enough, or would you need a different technique from the lecture?
# Name one.
#
# _Your answer:_
# If `sales_df` grew 50x larger, with potentially millions of rows, two sliders would likely *not* be enough to maintain interactive performance. The real-time filtering and re-rendering of scatter plots would become sluggish, degrading the user experience.
#
# In this scenario, a more appropriate technique from the lecture would be **data aggregation with drill-down**. Instead of plotting every single point, we could start with an aggregated view (e.g., binned scatter plots or heatmaps for `unit_price` vs `units_sold`) that can handle the larger dataset efficiently. Then, as the user selects a region of interest on the aggregated view, they could "drill down" to see the individual points or a finer-grained aggregation within that specific range. This maintains interactivity by only loading or rendering detailed data for focused areas.

# %% [markdown]
# ## Task 3 — Coordinated Views & Cross-View Brushing: Compare Stores Without Flipping Pages
#
# **Real-world usage:** Complaint #2 — "comparing stores means flipping between many PDF pages."
# A manager wants to click one store in an overview chart and instantly see that store's category
# breakdown and its monthly trend, without losing sight of how it compares to the others.
#
# **Why this technique:** Coordinated multiple views + brushing (Slide 24) — selecting a subset in one
# view highlights the same records everywhere else, replacing the working-memory cost of flipping pages.
#
# ### Your task
# Build **three linked views** for a store the user selects from a dropdown:
# 1. **Overview bar chart** — total revenue per store (all 6 stores), with the selected store's bar in
#    a distinct color and every other store's bar in gray (this is the "muted unselected categories"
#    trick from the slide).
# 2. **Category breakdown** — a pie or bar chart of revenue by `category`, filtered to the selected
#    store only.
# 3. **Monthly trend line** — revenue by `month`, filtered to the selected store only.
#
# Wrap all three in one function driven by a single `ipywidgets.Dropdown` of `store_id` values, and lay
# the three charts out together (e.g. with `plt.subplots` for 1+2+3, or separate `display()` calls).

# %%
store_overview = sales_df.groupby("store_id").revenue.sum().reset_index()

def store_coordinated_view(selected_store):
    fig, axes = plt.subplots(1, 3, figsize=(20, 6))

    # TODO 1: bar chart of store_overview, selected store highlighted, others muted gray
    colors = ['skyblue' if s_id == selected_store else 'lightgray' for s_id in store_overview['store_id']]
    sns.barplot(x='store_id', y='revenue', data=store_overview, palette=colors, ax=axes[0])
    axes[0].set_title('Total Revenue per Store (Overview)')
    axes[0].set_xlabel('Store ID')
    axes[0].set_ylabel('Total Revenue')

    # TODO 2: category breakdown pie/bar for selected_store only
    selected_store_data = sales_df[sales_df['store_id'] == selected_store]
    category_breakdown = selected_store_data.groupby('category')['revenue'].sum().reset_index()
    sns.barplot(x='category', y='revenue', data=category_breakdown, palette='viridis', ax=axes[1])
    axes[1].set_title(f'Category Revenue Breakdown for {selected_store}')
    axes[1].set_xlabel('Category')
    axes[1].set_ylabel('Revenue')
    axes[1].tick_params(axis='x', rotation=45)

    # TODO 3: monthly revenue trend line for selected_store only
    monthly_trend = selected_store_data.groupby('month')['revenue'].sum().reset_index()
    sns.lineplot(x='month', y='revenue', data=monthly_trend, marker='o', ax=axes[2])
    axes[2].set_title(f'Monthly Revenue Trend for {selected_store}')
    axes[2].set_xlabel('Month')
    axes[2].set_ylabel('Revenue')
    axes[2].tick_params(axis='x', rotation=45)

    plt.tight_layout()
    plt.show()

# TODO: wire this up with interact() using a Dropdown of stores["store_id"] values
store_dropdown = widgets.Dropdown(
    options=sales_df['store_id'].unique().tolist(),
    value=sales_df['store_id'].unique().tolist()[0],
    description='Select Store:'
)

interact(store_coordinated_view, selected_store=store_dropdown);
# Out:
# interactive(children=(Dropdown(description='Select Store:', options=('S01', 'S02', 'S03', 'S04', 'S05', 'S06')…

# %% [markdown]
# **Reflection:** Which of the three linked views above is playing the role of "context" and which is playing "focus," in the sense of the Focus-Context Problem (Slide 18)? Is that the same distinction as brushing, or a different but related idea? Explain briefly.
#
# _Your answer:_
# In the three linked views, the **Overview bar chart** (total revenue per store) plays the role of **context**. It displays all stores, providing a broad understanding of their relative performance.
#
# The **Category breakdown** and **Monthly trend line** charts, which are dynamically filtered to show data only for the *selected* store, play the role of **focus**. They provide detailed information about a specific store.
#
# This is essentially the same distinction as brushing, or a very closely related idea. Brushing is the *interaction technique* (selecting a subset of data in one view) that enables the **Focus + Context** presentation. By brushing on the overview (context) chart, the detailed (focus) charts are updated, allowing the user to dive deeper into specific data points while still being able to see where that detailed information fits within the larger picture.

# %% [markdown]
# ## Task 4 — Focus + Context Drill-Down: Investigate the Dip
#
# **Real-world usage:** Complaint #3 — "spotting a sudden dip is slow and easy to miss." One product at
# one store has a real anomaly hidden in `sales_df` (planted in Task 0). A manager needs to find it and
# drill in **without losing the overview**, using the *cheapest* interaction tier that still answers the
# question (Drill-Down Cost Hierarchy, Slide 17).
#
# ### Your task
# **Part A — find the anomaly.**
# Write code that computes, for every `(store_id, product)` pair, the ratio of the *minimum* month's
# `units_sold` to the *median* month's `units_sold` across the 24 months. Sort ascending and show the
# top 5 most extreme drops. (Hint: `groupby(["store_id","product"]).units_sold.agg(...)` with a custom
# function, or compute `min` and `median` separately and combine.)
#
# **Part B — build the drill-down.**
# Using **hover** (cheap tier) on an overview chart of all `(store_id, product)` trend lines, let the
# user identify the anomalous line. Then, given the `store_id`/`product` you found in Part A, plot its
# monthly trend **alongside** a faint gray context line showing the *average* trend across all
# stores/products for the same product — so the dip is visible with its context still present (not a
# full window replacement).

# %%
# --- Part A: find the anomaly ---
def min_to_median_ratio(series):
    min_val = series.min()
    median_val = series.median()
    if median_val == 0: # Avoid division by zero
        return 0 if min_val == 0 else -1 # Or some other indicator for infinite drop
    return min_val / median_val

anomaly_ranking = sales_df.groupby(["store_id", "product"])['units_sold'].agg(min_median_ratio=min_to_median_ratio)
anomaly_ranking = anomaly_ranking.sort_values(by="min_median_ratio", ascending=True)

print("Top 5 most extreme drops (min/median units_sold ratio):")
display(anomaly_ranking.head(5))
# Out:
# Top 5 most extreme drops (min/median units_sold ratio):
#                        min_median_ratio
# store_id product
# S03      Smartwatch            0.185714
# S05      USB-C Hub             0.250000
# S01      Track Jacket          0.300000
# S03      USB-C Hub             0.303030
# S02      Yoga Mat              0.315789

# %%
# --- Part B: drill-down with context preserved ---
# TODO 1: build an overview plotly line chart of units_sold over month, one line per (store_id, product)
#         combination, with hover showing store_id + product (cheap-tier epistemic action)

# Prepare data for overview chart: ensure month is treated as a continuous variable for plotly
overview_data = sales_df.copy()
overview_data['store_product'] = overview_data['store_id'] + ' - ' + overview_data['product']

fig_overview = px.line(
    overview_data,
    x='month',
    y='units_sold',
    color='store_product',
    title='Units Sold Over Time by Store and Product (Overview)',
    hover_data=['store_id', 'product']
)
fig_overview.show()

# TODO 2: using the (store_id, product) pair you identified as the top anomaly in Part A,
#         plot its monthly units_sold trend (focus) together with the average trend for that SAME
#         product across all other stores (context), on one shared chart

# Get the top anomalous (store_id, product) pair from anomaly_ranking
top_anomaly = anomaly_ranking.index[0]
anomaly_store_id = top_anomaly[0]
anomaly_product = top_anomaly[1]

# Focus data: units_sold trend for the anomalous store and product
focus_data = sales_df[
    (sales_df['store_id'] == anomaly_store_id) &
    (sales_df['product'] == anomaly_product)
].sort_values('month')

# Context data: average units_sold trend for the same product across all OTHER stores
context_data = sales_df[
    (sales_df['product'] == anomaly_product) &
    (sales_df['store_id'] != anomaly_store_id)
].groupby('month')['units_sold'].mean().reset_index()

plt.figure(figsize=(12, 7))
sns.lineplot(x='month', y='units_sold', data=focus_data, marker='o', label=f'{anomaly_store_id} - {anomaly_product} (Focus)', color='red')
sns.lineplot(x='month', y='units_sold', data=context_data, marker='x', label=f'Average for {anomaly_product} (Context)', color='gray', linestyle='--')

plt.title(f'Units Sold Trend for {anomaly_store_id} - {anomaly_product} vs. Product Average')
plt.xlabel('Month')
plt.ylabel('Units Sold')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ec50911e-5068-4d38-a1a1-d48eb7fc160c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec50911e-5068-4d38-a1a1-d48eb7fc160c")) {                    Plotly.newPlot(                        "ec50911e-5068-4d38-a1a1-d48eb7fc160c",                        [{"customdata":[["S01","Wireless Earbuds"],["S01","Wireless Earbuds"],["S01","Wireless Earbuds"],["S01","Wireless Earbuds"],["S01","Wireless Earbuds"],["S01","Wireless Earbuds"],["S01","Wireless Earbuds"],["S01","Wireless Earbuds"],["S01","Wireless Earbuds"],["S01","Wireless Earbuds"],["S01","Wireless Earbuds"],["S01","Wireless Earbuds"],["S01","Wireless Earbuds"],["S01","Wireless Earbuds"],["S01","Wireless Earbuds"],["S01","Wireless Earbuds"],["S01","Wireless Earbuds"],["S01","Wireless Earbuds"],["S01","Wireless Earbuds"],["S01","Wireless Earbuds"],["S01","Wireless Earbuds"],["S01","Wireless Earbuds"],["S01","Wireless Earbuds"],["S01","Wireless Earbuds"]],"hovertemplate":"store_product=S01 - Wireless Earbuds\u003cbr\u003emonth=%{x}\u003cbr\u003eunits_sold=%{y}\u003cbr\u003estore_id=%{customdata[0]}\u003cbr\u003eproduct=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"S01 - Wireless Earbuds","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"S01 - Wireless Earbuds","showlegend":true,"x":["2023-01-01T00:00:00","2023-02-01T00:00:00","2023-03-01T00:00:00","2023-04-01T00:00:00","2023-05-01T00:00:00","2023-06-01T00:00:00","2023-07-01T00:00:00","2023-08-01T00:00:00","2023-09-01T00:00:00","2023-10-01T00:00:00","2023-11-01T00:00:00","2023-12-01T00:00:00","2024-01-01T00:00:00","2024-02-01T00:00:00","2024-03-01T00:00:00","2024-04-01T00:00:00","2024-05-01T00:00:00","2024-06-01T00:00:00","2024-07-01T00:00:00","2024-08-01T00:00:00","2024-09-01T00:00:00","2024-10-01T00:00:00","2024-11-01T00:00:00","2024-12-01T00:00:00"],"xaxis":"x","y":[17.0,19.0,16.0,31.0,22.0,18.0,19.0,12.0,14.0,22.0,19.0,24.0,14.0,26.0,32.0,26.0,26.0,25.0,19.0,23.0,24.0,25.0,25.0,40.0],"yaxis":"y","type":"scattergl"},{"customdata":[["S01","Smartwatch"],["S01","Smartwatch"],["S01","Smartwatch"],["S01","Smartwatch"],["S01","Smartwatch"],["S01","Smartwatch"],["S01","Smartwatch"],["S01","Smartwatch"],["S01","Smartwatch"],["S01","Smartwatch"],["S01","Smartwatch"],["S01","Smartwatch"],["S01","Smartwatch"],["S01","Smartwatch"],["S01","Smartwatch"],["S01","Smartwatch"],["S01","Smartwatch"],["S01","Smartwatch"],["S01","Smartwatch"],["S01","Smartwatch"],["S01","Smartwatch"],["S01","Smartwatch"],["S01","Smartwatch"],["S01","Smartwatch"]],"hovertemplate":"store_product=S01 - Smartwatch\u003cbr\u003emonth=%{x}\u003cbr\u003eunits_sold=%{y}\u003cbr\u003estore_id=%{customdata[0]}\u003cbr\u003eproduct=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"S01 - Smartwatch","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"S01 - Smartwatch","showlegend":true,"x":["2023-01-01T00:00:00","2023-02-01T00:00:00","2023-03-01T00:00:00","2023-04-01T00:00:00","2023-05-01T00:00:00","2023-06-01T00:00:00","2023-07-01T00:00:00","2023-08-01T00:00:00","2023-09-01T00:00:00","2023-10-01T00:00:00","2023-11-01T00:00:00","2023-12-01T00:00:00","2024-01-01T00:00:00","2024-02-01T00:00:00","2024-03-01T00:00:00","2024-04-01T00:00:00","2024-05-01T00:00:00","2024-06-01T00:00:00","2024-07-01T00:00:00","2024-08-01T00:00:00","2024-09-01T00:00:00","2024-10-01T00:00:00","2024-11-01T00:00:00","2024-12-01T00:00:00"],"xaxis":"x","y":[11.0,8.0,8.0,13.0,7.0,8.0,9.0,7.0,7.0,12.0,10.0,6.0,14.0,14.0,16.0,18.0,11.0,5.0,11.0,10.0,9.0,5.0,11.0,13.0],"yaxis":"y","type":"scattergl"},{"customdata":[["S01","Laptop Sleeve"],["S01","Laptop Sleeve"],["S01","La ...

# %% [markdown]
# **Reflection:** Which interaction-cost tier (eye fixation / hover / click-to-open panel / window replacement) did you use to first *spot* the anomaly, and which did you use to *investigate* it? Was using two different tiers the right call, per the lecture's design rule?
#
# _Your answer:_
# To first *spot* the anomaly, I used a **hover** interaction on the overview Plotly line chart (Task 4, Part B). Hovering over different lines allowed for quick inspection of individual trends without committing to a click or opening a new panel, which is a cheap tier of interaction.
#
# To *investigate* the anomaly, I used a **window replacement** (a new `matplotlib` plot showing the focus anomaly and context). This is a higher interaction-cost tier, but it was justified for a deeper, comparative analysis of the specific anomalous trend against its product's average.
#
# Using two different tiers was indeed the right call, per the lecture's design rule (Drill-Down Cost Hierarchy). It allowed for a low-cost initial scan and identification, followed by a more expensive, dedicated view for detailed investigation, preventing cognitive overload during the initial search while providing necessary depth for understanding the issue.

# %% [markdown]
# ## Task 5 — Table Lens: A Scannable Product Performance Table
#
# **Real-world usage:** A manager wants a single table listing every product's total revenue, total
# profit, and average rating across all stores — but a plain spreadsheet of 10 rows x many numeric
# columns is still hard to compare at a glance across all three metrics simultaneously.
#
# **Why this technique:** Table Lens (Slide 27) maps numeric columns to in-cell bars, so magnitude
# differences are visible pre-attentively while the table stays sortable/readable as text.
#
# ### Your task
# 1. Build a summary DataFrame: one row per `product`, columns for total `revenue`, total `profit`, and
#    mean `avg_rating`.
# 2. Sort it by total revenue, descending.
# 3. Style it as a Table Lens using `.style.bar(...)` — a different bar color per numeric column, as in
#    the Demo notebook — and add a meaningful `.set_caption(...)`.
# 4. Below the table, add **one more cell**: sort the *same* summary table by `profit` instead of
#    `revenue`, and re-render the styled table. Do the top rows change order? Note what that tells a
#    manager about revenue vs. profitability.

# %%
# TODO: build product_summary with columns: product, revenue (sum), profit (sum), avg_rating (mean)
product_summary = sales_df.groupby('product').agg(
    revenue=('revenue', 'sum'),
    profit=('profit', 'sum'),
    avg_rating=('avg_rating', 'mean')
).reset_index()

# TODO: sort descending by revenue
product_summary = product_summary.sort_values(by='revenue', ascending=False)

# TODO: style with .style.bar(...) per numeric column + .set_caption(...)
styled_product_summary_revenue = product_summary.style.bar(subset=['revenue'], color='skyblue') \
                                              .bar(subset=['profit'], color='lightgreen') \
                                              .bar(subset=['avg_rating'], color='salmon') \
                                              .set_caption("Product Performance by Total Revenue (Descending)")

display(styled_product_summary_revenue)
# Out:
# <style type="text/css">
# #T_0a196_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, skyblue 100.0%, transparent 100.0%);
# }
# #T_0a196_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 100.0%, transparent 100.0%);
# }
# #T_0a196_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 99.0%, transparent 99.0%);
# }
# #T_0a196_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, skyblue 69.4%, transparent 69.4%);
# }
# #T_0a196_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 66.8%, transparent 66.8%);
# }
# #T_0a196_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 97.7%, transparent 97.7%);
# }
# #T_0a196_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, skyblue 61.7%, transparent 61.7%);
# }
# #T_0a196_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 59.3%, transparent 59.3%);
# }
# #T_0a196_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 99.2%, transparent 99.2%);
# }
# #T_0a196_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, skyblue 49.6%, transparent 49.6%);
# }
# #T_0a196_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 47.1%, transparent 47.1%);
# }
# #T_0a196_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 99.6%, transparent 99.6%);
# }
# #T_0a196_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, skyblue 48.7%, transparent 48.7%);
# }
# #T_0a196_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 47.9%, transparent 47.9%);
# }
# #T_0a196_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 97.8%, transparent 97.8%);
# }
# #T_0a196_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, skyblue 44.5%, transparent 44.5%);
# }
# #T_0a196_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 41.5%, transparent 41.5%);
# }
# #T_0a196_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 100.0%, transparent 100.0%);
# }
# #T_0a196_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, skyblue 24.5%, transparent 24.5%);
# }
# #T_0a196_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 23.4%, transparent 23.4%);
# }
# #T_0a196_row6_col3, #T_0a196_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 98.9%, transparent 98.9%);
# }
# #T_0a196_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, skyblue 24.0%, transparent 24.0%);
# }
# #T_0a196_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 22.9%, transparent 22.9%);
# }
# #T_0a196_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, skyblue 17.8%, transparent 17.8%);
# }
# #T_0a196_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 17.1%, transparent 17.1%);
# }
# #T_0a196_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 98.7%, transparent 98.7%);
# }
# #T_0a196_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, skyblue 9.9%, transparent 9.9%);
# }
# #T_0a196_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 9.6%, transparent 9.6%);
# }
# #T_0a196_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 98.5%, transparent 98.5%);
# }
# </style>
# <table id="T_0a196" class="dataframe">
#   <caption>Product Performance by Total Revenue (Descending)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a196_level0_col0" class="col_heading level0 col0" >product</th>
#       <th id="T_0a196_level0_col1" class="col_heading level0 col1" >revenue</th>
#       <th id="T_0a196_level0_col2" class="col_heading level0 col2" >profit</th>
#       <th id="T_0a196_level0_col3" class="col_heading level0 col3" >avg_rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a196_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_0a196_row0_col0" class="data row0 col0" >Smartwatch</td>
#       <td id="T_0a196_row0_col1" class="data row0 col1" >15706358.100000</td>
#       <td id="T_0a196_row0_col2" class="data row0 col2" >3881507.114978</td>
#       <td id="T_0a196_row0_col3" class="data row0 col3" >4.088194</td>
#     </tr>
#     <tr>
#       <th id="T_0a196_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_0a196_row1_col0" class="data row1 col0" >Air Fryer</td>
#       <td id="T_0a196_row1_col1" class="data row1 col1" >10901274.000000</td>
#       <td id="T_0a196_row1_col2" class="data row1 col2" >2593731.370256</td>
#       <td id="T_0a196_row1_col3" class="data row1 col3" >4.036111</td>
#     </tr>
#     <tr>
#       <th id="T_0a196_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_0a196_row2_col0" class="data row2 col0" >Running Shoes</td>
#       <td id="T_0a196_row2_col1" class="data row2 col1" >9688731.000000</td>
#       <td id="T_0a196_row2_col2" class="data row2 col2" >2303074.979248</td>
#       <td id="T_0a196_row2_col3" class="data row2 col3" >4.100000</td>
#     </tr>
#     <tr>
#       <th id="T_0a196_level0_row3" class="row_heading level0 row3" >2</th>
#       <td id="T_0a196_row3_col0" class="data row3 col0" >Dumbbell Set</td>
#       <td id="T_0a196_row3_col1" class="data row3 col1" >7796880.000000</td>
#       <td id="T_0a196_row3_col2" class="data row3 col2" >1829126.919623</td>
#       <td id="T_0a196_row3_col3" class="data row3 col3" >4.113889</td>
#     </tr>
#     <tr>
#       <th id="T_0a196_level0_row4" class="row_heading level0 row4" >1</th>
#       <td id="T_0a196_row4_col0" class="data row4 col0" >Blender</td>
#       <td id="T_0a196_row4_col1" class="data row4 col1" >7648773.000000</td>
#       <td id="T_0a196_row4_col2" class="data row4 col2" >1860308.558382</td>
#       <td id="T_0a196_row4_col3" class="data row4 col3" >4.039583</td>
#     </tr>
#     <tr>
#       <th id="T_0a196_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_0a196_row5_col0" class="data row5 col0" >Track Jacket</td>
#       <td id="T_0a196_row5_col1" class="data row5 col1" >6992502.000000</td>
#       <td id="T_0a196_row5_col2" class="data row5 col2" >1610283.087008</td>
#       <td id="T_0a196_row5_col3" class="data row5 col3" >4.131250</td>
#     </tr>
#     <tr>
#       <th id="T_0a196_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_0a196_row6_col0" class="data row6 col0" >USB-C Hub</td>
#       <td id="T_0a196_row6_col1" class="data row6 col1" >3842442.000000</td>
#       <td id="T_0a196_row6_col2" class="data row6 col2" >907435.115420</td>
#       <td id="T_0a196_row6_col3" class="data row6 col3" >4.087500</td>
#     </tr>
#     <tr>
#       <th id="T_0a196_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_0a196_row7_col0" class="data row7 col0" >Wireless Earbuds</td>
#       <td id="T_0a196_row7_col1" class="data row7 col1" >3769985.000000</td>
#       <td id="T_0a196_row7_col2" class="data row7 col2" >890553.519307</td>
#       <td id="T_0a196_row7_col3" class="data row7 col3" >4.086806</td>
#     </tr>
#     <tr>
#       <th id="T_0a196_level0_row8" class="row_heading level0 row8" >3</th>
#       <td id="T_0a196_row8_col0" class="data row8 col0" >Laptop Sleeve</td>
#       <td id="T_0a196_row8_col1" class="data row8 col1" >2801284.000000</td>
#       <td id="T_0a196_row8_col2" class="data row8 col2" >664357.720743</td>
#       <td id="T_0a196_row8_col3" class="data row8 col3" >4.076389</td>
#     </tr>
#     <tr>
#       <th id="T_0a196_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0a196_row9_col0" class="data row9 col0" >Yoga Mat</td>
#       <td id="T_0a196_row9_col1" class="data row9 col1" >1560447.000000</td>
#       <td id="T_0a196_row9_col2" class="data row9 col2" >370892.396491</td>
#       <td id="T_0a196_row9_col3" class="data row9 col3" >4.068750</td>
#     </tr>
#   </tbody>
# </table>

# %%
# TODO: re-sort product_summary by profit descending and re-render the styled table
product_summary_by_profit = product_summary.sort_values(by='profit', ascending=False)

styled_product_summary_profit = product_summary_by_profit.style.bar(subset=['revenue'], color='skyblue') \
                                                    .bar(subset=['profit'], color='lightgreen') \
                                                    .bar(subset=['avg_rating'], color='salmon') \
                                                    .set_caption("Product Performance by Total Profit (Descending)")

display(styled_product_summary_profit)
# Out:
# <style type="text/css">
# #T_f8590_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, skyblue 100.0%, transparent 100.0%);
# }
# #T_f8590_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 100.0%, transparent 100.0%);
# }
# #T_f8590_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 99.0%, transparent 99.0%);
# }
# #T_f8590_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, skyblue 69.4%, transparent 69.4%);
# }
# #T_f8590_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 66.8%, transparent 66.8%);
# }
# #T_f8590_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 97.7%, transparent 97.7%);
# }
# #T_f8590_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, skyblue 61.7%, transparent 61.7%);
# }
# #T_f8590_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 59.3%, transparent 59.3%);
# }
# #T_f8590_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 99.2%, transparent 99.2%);
# }
# #T_f8590_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, skyblue 48.7%, transparent 48.7%);
# }
# #T_f8590_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 47.9%, transparent 47.9%);
# }
# #T_f8590_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 97.8%, transparent 97.8%);
# }
# #T_f8590_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, skyblue 49.6%, transparent 49.6%);
# }
# #T_f8590_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 47.1%, transparent 47.1%);
# }
# #T_f8590_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 99.6%, transparent 99.6%);
# }
# #T_f8590_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, skyblue 44.5%, transparent 44.5%);
# }
# #T_f8590_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 41.5%, transparent 41.5%);
# }
# #T_f8590_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 100.0%, transparent 100.0%);
# }
# #T_f8590_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, skyblue 24.5%, transparent 24.5%);
# }
# #T_f8590_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 23.4%, transparent 23.4%);
# }
# #T_f8590_row6_col3, #T_f8590_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 98.9%, transparent 98.9%);
# }
# #T_f8590_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, skyblue 24.0%, transparent 24.0%);
# }
# #T_f8590_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 22.9%, transparent 22.9%);
# }
# #T_f8590_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, skyblue 17.8%, transparent 17.8%);
# }
# #T_f8590_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 17.1%, transparent 17.1%);
# }
# #T_f8590_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 98.7%, transparent 98.7%);
# }
# #T_f8590_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, skyblue 9.9%, transparent 9.9%);
# }
# #T_f8590_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 9.6%, transparent 9.6%);
# }
# #T_f8590_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 98.5%, transparent 98.5%);
# }
# </style>
# <table id="T_f8590" class="dataframe">
#   <caption>Product Performance by Total Profit (Descending)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8590_level0_col0" class="col_heading level0 col0" >product</th>
#       <th id="T_f8590_level0_col1" class="col_heading level0 col1" >revenue</th>
#       <th id="T_f8590_level0_col2" class="col_heading level0 col2" >profit</th>
#       <th id="T_f8590_level0_col3" class="col_heading level0 col3" >avg_rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8590_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_f8590_row0_col0" class="data row0 col0" >Smartwatch</td>
#       <td id="T_f8590_row0_col1" class="data row0 col1" >15706358.100000</td>
#       <td id="T_f8590_row0_col2" class="data row0 col2" >3881507.114978</td>
#       <td id="T_f8590_row0_col3" class="data row0 col3" >4.088194</td>
#     </tr>
#     <tr>
#       <th id="T_f8590_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_f8590_row1_col0" class="data row1 col0" >Air Fryer</td>
#       <td id="T_f8590_row1_col1" class="data row1 col1" >10901274.000000</td>
#       <td id="T_f8590_row1_col2" class="data row1 col2" >2593731.370256</td>
#       <td id="T_f8590_row1_col3" class="data row1 col3" >4.036111</td>
#     </tr>
#     <tr>
#       <th id="T_f8590_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_f8590_row2_col0" class="data row2 col0" >Running Shoes</td>
#       <td id="T_f8590_row2_col1" class="data row2 col1" >9688731.000000</td>
#       <td id="T_f8590_row2_col2" class="data row2 col2" >2303074.979248</td>
#       <td id="T_f8590_row2_col3" class="data row2 col3" >4.100000</td>
#     </tr>
#     <tr>
#       <th id="T_f8590_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_f8590_row3_col0" class="data row3 col0" >Blender</td>
#       <td id="T_f8590_row3_col1" class="data row3 col1" >7648773.000000</td>
#       <td id="T_f8590_row3_col2" class="data row3 col2" >1860308.558382</td>
#       <td id="T_f8590_row3_col3" class="data row3 col3" >4.039583</td>
#     </tr>
#     <tr>
#       <th id="T_f8590_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_f8590_row4_col0" class="data row4 col0" >Dumbbell Set</td>
#       <td id="T_f8590_row4_col1" class="data row4 col1" >7796880.000000</td>
#       <td id="T_f8590_row4_col2" class="data row4 col2" >1829126.919623</td>
#       <td id="T_f8590_row4_col3" class="data row4 col3" >4.113889</td>
#     </tr>
#     <tr>
#       <th id="T_f8590_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_f8590_row5_col0" class="data row5 col0" >Track Jacket</td>
#       <td id="T_f8590_row5_col1" class="data row5 col1" >6992502.000000</td>
#       <td id="T_f8590_row5_col2" class="data row5 col2" >1610283.087008</td>
#       <td id="T_f8590_row5_col3" class="data row5 col3" >4.131250</td>
#     </tr>
#     <tr>
#       <th id="T_f8590_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_f8590_row6_col0" class="data row6 col0" >USB-C Hub</td>
#       <td id="T_f8590_row6_col1" class="data row6 col1" >3842442.000000</td>
#       <td id="T_f8590_row6_col2" class="data row6 col2" >907435.115420</td>
#       <td id="T_f8590_row6_col3" class="data row6 col3" >4.087500</td>
#     </tr>
#     <tr>
#       <th id="T_f8590_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_f8590_row7_col0" class="data row7 col0" >Wireless Earbuds</td>
#       <td id="T_f8590_row7_col1" class="data row7 col1" >3769985.000000</td>
#       <td id="T_f8590_row7_col2" class="data row7 col2" >890553.519307</td>
#       <td id="T_f8590_row7_col3" class="data row7 col3" >4.086806</td>
#     </tr>
#     <tr>
#       <th id="T_f8590_level0_row8" class="row_heading level0 row8" >3</th>
#       <td id="T_f8590_row8_col0" class="data row8 col0" >Laptop Sleeve</td>
#       <td id="T_f8590_row8_col1" class="data row8 col1" >2801284.000000</td>
#       <td id="T_f8590_row8_col2" class="data row8 col2" >664357.720743</td>
#       <td id="T_f8590_row8_col3" class="data row8 col3" >4.076389</td>
#     </tr>
#     <tr>
#       <th id="T_f8590_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f8590_row9_col0" class="data row9 col0" >Yoga Mat</td>
#       <td id="T_f8590_row9_col1" class="data row9 col1" >1560447.000000</td>
#       <td id="T_f8590_row9_col2" class="data row9 col2" >370892.396491</td>
#       <td id="T_f8590_row9_col3" class="data row9 col3" >4.068750</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Your observation (revenue-sorted vs profit-sorted top rows):**
#
# Sorting by profit instead of revenue shows a significant change in the top-ranked products. For instance, 'Smartwatch' is still at the top, but 'Blender' (which was 5th by revenue) jumps ahead of 'Running Shoes' and 'Dumbbell Set' when sorted by profit. This indicates that while some products generate high revenue, they may not necessarily be the most profitable, and vice-versa. This distinction is crucial for managers deciding which products to push.

# %% [markdown]
# ## Task 6 — Assemble a Single-Screen Monitoring Dashboard (open-ended)
#
# **Real-world usage:** All three complaints at once. UrbanCart wants a **single screen** a regional
# manager can glance at every morning — no interaction required to read the headline state, per the
# Dashboard Patterns slide (Slide 28): critical indicators visible at a glance, with a peripheral-tier
# alert that uses color (not subtlety) to flag something that needs attention.
#
# ### Your task
# Build a 2x2 dashboard (`plt.subplots(2, 2, ...)`) with:
#
# 1. **Top-left — KPI summary panel** (`ax.axis("off")` + `ax.text(...)`): total revenue, total profit,
#    overall average rating, and number of active stores, computed from `sales_df`.
# 2. **Top-right — mid-term analysis panel**: revenue by `region` (bar chart).
# 3. **Bottom-left — long-term trend panel**: total revenue by `month`, across all stores (line chart).
# 4. **Bottom-right — peripheral alert panel**: check whether **any** `(store_id, product)` pair has a
#    month where `units_sold` fell below **25% of its own median** for that pair (this is the anomaly
#    you found in Task 4, but write the check generically so it would catch *any* such case, not just
#    the one you already know about). Show a red "ALERT — N issue(s) found" indicator if any exist, or
#    a green "OK" indicator if not.
#
# This task is intentionally the least scaffolded — you decide the exact `groupby` calls, panel layout
# details, and styling. Reuse patterns from Tasks 1-5 and the Demo notebook where they fit, but write
# the logic yourself.

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# --- Panel 1: KPI summary (top-left) ---
total_revenue = sales_df['revenue'].sum()
total_profit = sales_df['profit'].sum()
overall_avg_rating = sales_df['avg_rating'].mean()
num_active_stores = sales_df['store_id'].nunique()

axes[0, 0].axis('off')
axes[0, 0].text(0.5, 0.8, 'Overall KPIs', fontsize=16, ha='center', weight='bold')
axes[0, 0].text(0.1, 0.6, f'Total Revenue: ${total_revenue:,.2f}', fontsize=12)
axes[0, 0].text(0.1, 0.45, f'Total Profit: ${total_profit:,.2f}', fontsize=12)
axes[0, 0].text(0.1, 0.3, f'Avg Rating: {overall_avg_rating:.2f}', fontsize=12)
axes[0, 0].text(0.1, 0.15, f'Active Stores: {num_active_stores}', fontsize=12)

# --- Panel 2: revenue by region (top-right) ---
revenue_by_region = sales_df.groupby('region')['revenue'].sum().reset_index()
sns.barplot(x='region', y='revenue', data=revenue_by_region, ax=axes[0, 1], palette='crest')
axes[0, 1].set_title('Revenue by Region', fontsize=14)
axes[0, 1].set_xlabel('Region')
axes[0, 1].set_ylabel('Total Revenue')

# --- Panel 3: total revenue by month, all stores (bottom-left) ---
total_revenue_by_month = sales_df.groupby('month')['revenue'].sum().reset_index()
sns.lineplot(x='month', y='revenue', data=total_revenue_by_month, ax=axes[1, 0], marker='o', color='darkorange')
axes[1, 0].set_title('Total Revenue by Month', fontsize=14)
axes[1, 0].set_xlabel('Month')
axes[1, 0].set_ylabel('Total Revenue')
axes[1, 0].tick_params(axis='x', rotation=45)

# --- Panel 4: peripheral alert panel (bottom-right) ---
def check_anomaly(df):
    anomalies = 0
    for (store, product), group in df.groupby(['store_id', 'product']):
        median_units = group['units_sold'].median()
        if median_units > 0 and (group['units_sold'] < 0.25 * median_units).any():
            anomalies += 1
    return anomalies

num_anomalies = check_anomaly(sales_df)

axes[1, 1].axis('off')
if num_anomalies > 0:
    axes[1, 1].text(0.5, 0.5, f'ALERT — {num_anomalies} issue(s) found', fontsize=16, ha='center', va='center', color='red', weight='bold')
else:
    axes[1, 1].text(0.5, 0.5, 'OK', fontsize=16, ha='center', va='center', color='green', weight='bold')
axes[1, 1].set_title('Anomaly Detection', fontsize=14)

fig.suptitle("UrbanCart Regional Manager Dashboard", fontsize=18, y=1.02)
plt.tight_layout(rect=[0, 0, 1, 0.98]) # Adjust layout to prevent title overlap
plt.show()
# Out:
# /tmp/ipykernel_609/3691332582.py:18: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# ## Reflection
#
# Answer briefly, referring back to the three manager complaints from the scenario intro:
#
# 1. Which single technique from this activity do you think gives UrbanCart's managers the *biggest*
#    time saving, and why?
# 2. Which technique was hardest to implement well, and what design trade-off (from the lecture) did you
#    have to think about while building it?
# 3. If you had to add **one more** interaction technique from the lecture that this activity didn't
#    cover (e.g. geometric fisheye, magic lens, network zooming, model-based planning), where in this
#    retail scenario would it actually be useful, and why?
#
# _Your answers here._

# %% [markdown]
# ### Your answers here:
#
# 1. **Biggest time saving technique:** [Your Answer Here]
#
# 2. **Hardest technique to implement and design trade-off:** [Your Answer Here]
#
# 3. **One more interaction technique:** [Your Answer Here]

# %% [markdown]
# ### Your answers here:
#
# 1.  **Biggest time saving technique:** The Coordinated Views (Task 3) offer the biggest time saving. It directly addresses the complaint of having to flip between many pages to compare stores, allowing managers to instantly see category breakdowns and monthly trends for a selected store while still keeping other stores in context. This enables quick comparisons and drill-downs without needing to request new reports.
#
# 2.  **Hardest technique to implement well, and what design trade-off:** Implementing the Coordinated Views (Task 3) was arguably the hardest, especially ensuring the visual linking (highlighting the selected store, muting others) and the consistent data filtering across multiple subplots. The design trade-off I had to consider was **Focus + Context**. While providing a detailed 'focus' on a selected store, it was important to maintain 'context' by showing other stores in a muted gray in the overview bar chart. This prevents a complete window replacement and allows for better comparison without losing sight of the overall picture.
#
# 3.  **One more interaction technique:** I would add a **Magic Lens** interaction. In this retail scenario, it could be useful on a geographic map (e.g., displaying store locations). A manager could hover a 'lens' over a region to instantly see aggregated sales figures or key KPIs for only the stores within that lens's boundary, without having to filter the entire map or navigate to a new view. This would allow for localized data inspection while preserving the overall geographical context.
